# %% [markdown]
# # Tensorflowjs

# %%
# !pip install tensorflow

# %%
# !pip install tensorflowjs

# %%
from google.colab import drive
import os

# %%
# Montar Google Drive
drive.mount('/content/drive')

# Ruta a la carpeta birds_classification en Google Drive
data_folder = '/content/drive/My Drive/birds_classification/modelos'

# Listar archivos en la carpeta
files = os.listdir(data_folder)
print("Archivos en /birds_classification/modelos:", files)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archivos en /birds_classification/modelos: ['historial_birds_classification_model1.json', 'birds_classification_model1.h5', 'birds_classification_model2.h5', 'historial_birds_classification_model2.json', 'birds_classification_model3 (1).h5', 'historial_birds_classification_model3 (1).json', 'birds_classification_model3.h5', 'historial_birds_classification_model3.json']

# %%
# !cp '/content/drive/MyDrive/birds_classification/modelos/birds_classification_model3.h5' /content/

# %%
# Crear una carpeta donde se colocaran los archivos resultantes
# !mkdir carpeta_salida
# Out:
# mkdir: cannot create directory ‘carpeta_salida’: File exists

# %%
# Realizar la exportacion a la carpeta de salida
# !tensorflowjs_converter --input_format keras birds_classification_model3.h5 carpeta_salida
# Out:
# 2024-05-01 03:25:30.078742: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 03:25:31.990633: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Comprobar que en la carpeta se hayan generado los archivos
# !ls carpeta_salida
# Out:
# group1-shard10of14.bin	group1-shard14of14.bin	group1-shard4of14.bin  group1-shard8of14.bin
# group1-shard11of14.bin	group1-shard1of14.bin	group1-shard5of14.bin  group1-shard9of14.bin
# group1-shard12of14.bin	group1-shard2of14.bin	group1-shard6of14.bin  model.json
# group1-shard13of14.bin	group1-shard3of14.bin	group1-shard7of14.bin

# %%
# !zip -r modelojs1.zip /content/carpeta_salida/
# Out:
# updating: content/carpeta_salida/ (stored 0%)
# updating: content/carpeta_salida/group1-shard8of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard14of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard1of14.bin (deflated 7%)
# updating: content/carpeta_salida/group1-shard13of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard3of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard6of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard7of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard5of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard2of14.bin (deflated 7%)
# updating: content/carpeta_salida/model.json (deflated 97%)
# updating: content/carpeta_salida/group1-shard4of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard10of14.bin (deflated 8%)
# updating: content/carpeta_salida/group1-shard12of14.bin (deflated 8%)
# ...
